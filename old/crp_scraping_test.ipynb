# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json
import re

# %%
# try debugging this later
# from crpapi import CRP, CRPApiError

# %%
# read in your api key
with open('crp_api_key.json') as f:
    secret = json.load(f)

# %%
def get_ids_for_orgs(org_string, api_key):
    """
    Takes in a partial string of an organization's name, 
    and saves a dataframe of all organizations containing the string
    along with each organization's ID. 
    
    Also need to pass in your CRP API key.
    """
    url = f'https://www.opensecrets.org/api/?method=getOrgs&org={org_string}&apikey=' + api_key
    resp = requests.get(url)
    print(resp.status_code)
    soup = BeautifulSoup(resp.content, 'html.parser')
    org_ids = []
    org_names = []

    for org in soup.find_all('organization'):
        org_ids.append(org['orgid'])
        org_names.append(org['orgname'].strip())
        
    df = pd.DataFrame({'org_id':org_ids, 'org_names':org_names})  # change to org_name!!!
    filepath = 'data/crp_ids_' + org_string + '.csv'
    df.to_csv(filepath, index=False)
    print('Saved file', filepath)

# %%
# get_ids_for_orgs('Int', secret['api_key'])

# %%
df = pd.read_csv('data/crp_ids_Int.csv')
print(df.shape)
df.head(30)
# Out:
# (300, 2)
#         org_id                                          org_names
# 0   D000021803                                  ACA International
# 1   D000065572                                ACORN International
# 2   D000046437                               Advent International
# 3   D000071358                             Advocare International
# 4   D000046547                     Airports Council International
# 5   D000031360                              Airtech International
# 6   D000046619                               Albany International
# 7   D000031477                     American Defense International
# 8   D000023974            American Intellectual Property Law Assn
# 9   D000000123                       American International Group
# 10  D000069504             American Pacific International Capital
# 11  D000021834  American Society of Interventional Pain Physic...
# 12  D000047059                            American Structurepoint
# 13  D000069848                            Aristotle International
# 14  D000060171                               Assael International
# 15  D000021853            Automotive Free International Trade PAC
# 16  D000031721                                   AV International
# 17  D000031741                      Axiom International Investors
# 18  D000060250                                   Bardes Interiors
# 19  D000000643                               Baxter International
# 20  D000067085                   Bayview Hunters Point Foundation
# 21  D000047679                               Belkin International
# 22  D000060336                               Berner International
# 23  D000047864                                  Bluff Point Assoc
# 24  D000047988                              Bridgepoint Education
# 25  D000000478                              Brinker International
# 26  D000071437            British International School of Chicago
# 27  D000069805                           Bully Pulpit Interactive
# 28  D000032220                                 CACI International
# 29  D000032225                                  Cafritz Interests

# %% [markdown]
# Thoughts:
#
# - 20,000 (daily?) API limit of `getOrgs` calls
# - 2,000 limit on `orgSummary` calls. Create other accounts w/ fake email addresses?
# - Maybe we can pull org ids by partial strings? We'll get tons of duplicates, but can filter those out later
# - Brainstorm other ways to group org names (i.e., first three letters?)
# - Somehow filter down to contractors that we're most interested in?

# %% [markdown]
# #### Looping over CRP ids to scrape total contributions

# %%
contribs_all = pd.DataFrame()

for i, row in df.head(3).iterrows():    
    url = 'https://www.opensecrets.org/orgs/totals.php?id=' + row['org_id']
    resp = requests.get(url, headers = {'User-Agent': 'ua'})
    print(resp.status_code)
    
    tables = pd.read_html(resp.content)
    contribs = tables[0]
    contribs['org_id'] = row['org_id']
    contribs['org_name'] = row['org_names']  # FIX LATER (make singular)
    cols = list(contribs.columns.copy())
    cols.insert(0, cols.pop())
    cols.insert(0, cols.pop())
    contribs = contribs[cols]
    contribs_all = pd.concat([contribs_all, contribs])
    contribs_all = contribs_all.reset_index(drop=True)
# Out:
# 200
# 200
# 200

# %%
print(contribs_all.shape)
contribs_all.head()
# Out:
# (40, 12)
#        org_id           org_name Cycle     Total Democrats Republicans  \
# 0  D000021803  ACA International  2020   $28,500        $0     $28,500
# 1  D000021803  ACA International  2018  $207,000   $17,000    $190,000
# 2  D000021803  ACA International  2016  $244,250   $18,200    $226,050
# 3  D000021803  ACA International  2014  $215,250   $11,500    $198,750
# 4  D000021803  ACA International  2012  $256,967   $11,000    $245,967
#
#   % to Dems % to Repubs Individuals      PACs Soft (Indivs) Soft (Orgs)
# 0        0%        100%      $1,000   $27,500            $0          $0
# 1        8%         92%          $0  $207,000            $0          $0
# 2        8%         93%      $1,250  $243,000            $0          $0
# 3        5%         92%        $500  $214,750            $0          $0
# 4        4%         96%      $3,217  $253,750            $0          $0

# %% [markdown]
# Clean up `contribs_all`

# %%
contribs_all.columns = ['org_id','org_name','cycle','total','dems','repubs','pct_to_dems','pct_to_repubs','indivs','pacs','soft_indivs','soft_orgs']
contribs_all = contribs_all[contribs_all.cycle.str.lower().str.startswith('t') == False]
contribs_all.cycle = contribs_all.cycle.astype(int)
contribs_all = contribs_all[contribs_all.cycle > 2005]
print(contribs_all.shape)
contribs_all.head()
# Out:
# (21, 12)
#        org_id           org_name  cycle     total     dems    repubs  \
# 0  D000021803  ACA International   2020   $28,500       $0   $28,500
# 1  D000021803  ACA International   2018  $207,000  $17,000  $190,000
# 2  D000021803  ACA International   2016  $244,250  $18,200  $226,050
# 3  D000021803  ACA International   2014  $215,250  $11,500  $198,750
# 4  D000021803  ACA International   2012  $256,967  $11,000  $245,967
#
#   pct_to_dems pct_to_repubs  indivs      pacs soft_indivs soft_orgs
# 0          0%          100%  $1,000   $27,500          $0        $0
# 1          8%           92%      $0  $207,000          $0        $0
# 2          8%           93%  $1,250  $243,000          $0        $0
# 3          5%           92%    $500  $214,750          $0        $0
# 4          4%           96%  $3,217  $253,750          $0        $0

# %% [markdown]
# #### Looping over CRP ids to scrape affiliates
#
# Better to store the affiliates as a dictionary, rather than a df?

# %%
lm_df = pd.DataFrame({'org_id':['d000000104'], 'org_names':['Lockheed Martin']})
lm_df.head(3)
# Out:
#        org_id        org_names
# 0  d000000104  Lockheed Martin

# %%
affils_all = pd.DataFrame()

# for i, row in df.head(3).iterrows():  # test case: first 3
for i, row in lm_df.head(3).iterrows():  # test case: lockheed
    print(row['org_id'])
    for year in reversed(range(2006, 2019, 2)):

        url = 'https://www.opensecrets.org/orgs/totals.php?id=' + row['org_id'] + '&type=P&cycle=' + str(year)
        resp = requests.get(url, headers = {'User-Agent': 'ua'})
        print(resp.status_code)

        tables = pd.read_html(resp.content)

        if len(tables) > 1:  # affiliates table exists
            affils = tables[1]
            affils['org_id'] = row['org_id']
            affils['org_name'] = row['org_names']  # FIX LATER (make singular)
            affils['cycle'] = year
            cols = list(affils.columns.copy())
            cols.insert(0, cols.pop())
            cols.insert(0, cols.pop())
            cols.insert(0, cols.pop())
            affils = affils[cols]
            affils_all = pd.concat([affils_all, affils])
            affils_all = affils_all.reset_index(drop=True)
# Out:
# d000000104
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
print(affils_all.shape)
affils_all.head()
# Out:
# (45, 11)
#         org_id         org_name  cycle  \
# 0   d000000104  Lockheed Martin   2018
# 1   d000000104  Lockheed Martin   2018
# 2   d000000104  Lockheed Martin   2018
# 3   d000000104  Lockheed Martin   2018
# 4   d000000104  Lockheed Martin   2018
# 5   d000000104  Lockheed Martin   2018
# 6   d000000104  Lockheed Martin   2018
# 7   d000000104  Lockheed Martin   2016
# 8   d000000104  Lockheed Martin   2016
# 9   d000000104  Lockheed Martin   2016
# 10  d000000104  Lockheed Martin   2016
# 11  d000000104  Lockheed Martin   2016
# 12  d000000104  Lockheed Martin   2014
# 13  d000000104  Lockheed Martin   2014
# 14  d000000104  Lockheed Martin   2014
# 15  d000000104  Lockheed Martin   2012
# 16  d000000104  Lockheed Martin   2012
# 17  d000000104  Lockheed Martin   2012
# 18  d000000104  Lockheed Martin   2012
# 19  d000000104  Lockheed Martin   2012
# 20  d000000104  Lockheed Martin   2010
# 21  d000000104  Lockheed Martin   2010
# 22  d000000104  Lockheed Martin   2010
# 23  d000000104  Lockheed Martin   2010
# 24  d000000104  Lockheed Martin   2010
# 25  d000000104  Lockheed Martin   2010
# 26  d000000104  Lockheed Martin   2008
# 27  d000000104  Lockheed Martin   2008
# 28  d000000104  Lockheed Martin   2008
# 29  d000000104  Lockheed Martin   2008
# 30  d000000104  Lockheed Martin   2008
# 31  d000000104  Lockheed Martin   2008
# 32  d000000104  Lockheed Martin   2008
# 33  d000000104  Lockheed Martin   2008
# 34  d000000104  Lockheed Martin   2008
# 35  d000000104  Lockheed Martin   2008
# 36  d000000104  Lockheed Martin   2006
# 37  d000000104  Lockheed Martin   2006
# 38  d000000104  Lockheed Martin   2006
# 39  d000000104  Lockheed Martin   2006
# 40  d000000104  Lockheed Martin   2006
# 41  d000000104  Lockheed Martin   2006
# 42  d000000104  Lockheed Martin   2006
# 43  d000000104  Lockheed Martin   2006
# 44  d000000104  Lockheed Martin   2006
#
#                                  Affiliate    Total     Dems   Repubs  \
# 0                   Lockheed Fort Worth Co     $388       $0     $388
# 1              Lockheed Martin Aeronautics  $22,066   $1,306  $19,970
# 2   Lockheed Martin Information Technology     $480     $330     $150
# 3            Lockheed Martin Space Systems     $706     $396     $310
# 4                     Martin Marietta Corp     $700       $0     $700
# 5                          Savi Technology     $610     $610       $0
# 6                        Sikorsky Aircraft   $4,457   $1,416   $2,899
# 7              Lockheed Martin Aeronautics  $46,870   $6,090  $40,613
# 8   Lockheed Martin Information Technology     $250       $0     $250
# 9            Lockheed Martin Space Systems   $2,883     $781   $1,640
# 10                         Savi Technology     $350     $350       $0
# 11                       Sikorsky Aircraft  $10,629   $4,279   $6,350
# 12             Lockheed Martin Aeronautics  $22,539   $1,250  $20,825
# 13  Lockheed Martin Information Technology     $500       $0     $500
# 14           Lockheed Martin Space Systems     $951       $0     $951
# 15             Lockheed Martin Aeronautics  $36,385   $1,250  $35,135
# 16  Lockheed Martin Information Technology     $401       $0     $401
# 17        Lockheed Martin Missiles & Space     $250     $250       $0
# 18           Lockheed Martin Space Systems   $6,674   $3,724   $2,450
# 19                         Savi Technology     $500     $250     $250
# 20                Lockheed Martin Aculight     $250     $250       $0
# 21             Lockheed Martin Aeronautics  $13,728       $0  $13,728
# 22  Lockheed Martin Information Technology     $500     $500       $0
# 23        Lockheed Martin Missiles & Space   $1,100     $800     $300
# 24           Lockheed Martin Space Systems     $500     $500       $0
# 25                    Martin Marietta Corp   $8,500   $2,500   $6,000
# 26                      Aspen Systems Corp     $300     $300       $0
# 27                             COMSAT Corp     $500       $0     $500
# 28             Lockheed Martin Aeronautics  $36,157   $1,050  $34,552
# 29      Lockheed Martin Electronic Systems   $1,000   $1,000       $0
# 30         Lockheed Martin Energy Research     $400       $0     $400
# 31  Lockheed Martin Information Technology     $750       $0     $750
# 32        Lockheed Martin Missiles & Space     $750     $500     $250
# 33           Lockheed Martin Space Systems   $3,908   $1,158   $2,750
# 34                         Savi Technology   $2,250   $1,750     $500
# 35                            Sippican Inc  $19,800  $15,500   $4,300
# 36                      Aspen Systems Corp   $1,500   $1,500       $0
# 37                             COMSAT Corp     $750       $0     $750
# 38             Lockheed Martin Aeronautics   $1,900       $0   $1,900
# 39         Lockheed Martin Energy Research   $1,000   $1,000       $0
# 40           Lockheed Martin Space Systems     $700     $700       $0
# 41                            Orincon Corp   $9,460   $2,460   $7,000
# 42                         Orincon Sygenex   $1,000       $0   $1,000
# 43            Sandia National Laboratories  $35,433  $13,583  $20,650
# 44                         Savi Technology   $3,750   $2,750   $1,000
#
#    % to Dems % to Repubs   Indivs PACs
# 0         0%        100%     $388   $0
# 1         6%         91%  $22,066   $0
# 2        69%         31%     $480   $0
# 3        56%         44%     $706   $0
# 4         0%        100%     $700   $0
# 5       100%          0%     $610   $0
# 6        32%         65%   $4,457   $0
# 7        13%         87%  $46,870   $0
# 8         0%        100%     $250   $0
# 9        27%         57%   $2,421   $0
# 10      100%          0%     $350   $0
# 11       40%         60%  $10,629   $0
# 12        6%         92%  $22,539   $0
# 13        0%        100%     $500   $0
# 14        0%        100%     $951   $0
# 15        3%         97%  $36,385   $0
# 16        0%        100%     $401   $0
# 17      100%          0%     $250   $0
# 18       56%         37%   $6,174   $0
# 19       50%         50%     $500   $0
# 20      100%          0%     $250   $0
# 21        0%        100%  $13,728   $0
# 22      100%          0%     $500   $0
# 23       73%         27%   $1,100   $0
# 24      100%          0%     $500   $0
# 25       29%         71%   $8,500   $0
# 26      100%          0%     $300   $0
# 27        0%        100%     $500   $0
# 28        3%         96%  $35,602   $0
# 29      100%          0%   $1,000   $0
# 30        0%        100%     $400   $0
# 31        0%        100%     $750   $0
# 32       67%         33%     $750   $0
# 33       30%         70%   $3,908   $0
# 34       78%         22%   $2,250   $0
# 35       78%         22%  $19,800   $0
# 36      100%          0%   $1,500   $0
# 37        0%        100%     $750   $0
# 38        0%        100%   $1,900   $0
# 39      100%          0%   $1,000   $0
# 40      100%          0%     $700   $0
# 41       26%         74%   $9,460   $0
# 42        0%        100%   $1,000   $0
# 43       38%         58%  $35,233   $0
# 44       73%         27%   $3,750   $0

# %% [markdown]
# Clean up `affils_all`

# %%
affils_all.columns = ['org_id','org_name','cycle','affiliate','total','dems','repubs','pct_to_dems','pct_to_repubs','indivs','pacs']
print(affils_all.shape)
affils_all
# Out:
# (45, 11)
#         org_id         org_name  cycle  \
# 0   d000000104  Lockheed Martin   2018
# 1   d000000104  Lockheed Martin   2018
# 2   d000000104  Lockheed Martin   2018
# 3   d000000104  Lockheed Martin   2018
# 4   d000000104  Lockheed Martin   2018
# 5   d000000104  Lockheed Martin   2018
# 6   d000000104  Lockheed Martin   2018
# 7   d000000104  Lockheed Martin   2016
# 8   d000000104  Lockheed Martin   2016
# 9   d000000104  Lockheed Martin   2016
# 10  d000000104  Lockheed Martin   2016
# 11  d000000104  Lockheed Martin   2016
# 12  d000000104  Lockheed Martin   2014
# 13  d000000104  Lockheed Martin   2014
# 14  d000000104  Lockheed Martin   2014
# 15  d000000104  Lockheed Martin   2012
# 16  d000000104  Lockheed Martin   2012
# 17  d000000104  Lockheed Martin   2012
# 18  d000000104  Lockheed Martin   2012
# 19  d000000104  Lockheed Martin   2012
# 20  d000000104  Lockheed Martin   2010
# 21  d000000104  Lockheed Martin   2010
# 22  d000000104  Lockheed Martin   2010
# 23  d000000104  Lockheed Martin   2010
# 24  d000000104  Lockheed Martin   2010
# 25  d000000104  Lockheed Martin   2010
# 26  d000000104  Lockheed Martin   2008
# 27  d000000104  Lockheed Martin   2008
# 28  d000000104  Lockheed Martin   2008
# 29  d000000104  Lockheed Martin   2008
# 30  d000000104  Lockheed Martin   2008
# 31  d000000104  Lockheed Martin   2008
# 32  d000000104  Lockheed Martin   2008
# 33  d000000104  Lockheed Martin   2008
# 34  d000000104  Lockheed Martin   2008
# 35  d000000104  Lockheed Martin   2008
# 36  d000000104  Lockheed Martin   2006
# 37  d000000104  Lockheed Martin   2006
# 38  d000000104  Lockheed Martin   2006
# 39  d000000104  Lockheed Martin   2006
# 40  d000000104  Lockheed Martin   2006
# 41  d000000104  Lockheed Martin   2006
# 42  d000000104  Lockheed Martin   2006
# 43  d000000104  Lockheed Martin   2006
# 44  d000000104  Lockheed Martin   2006
#
#                                  affiliate    total     dems   repubs  \
# 0                   Lockheed Fort Worth Co     $388       $0     $388
# 1              Lockheed Martin Aeronautics  $22,066   $1,306  $19,970
# 2   Lockheed Martin Information Technology     $480     $330     $150
# 3            Lockheed Martin Space Systems     $706     $396     $310
# 4                     Martin Marietta Corp     $700       $0     $700
# 5                          Savi Technology     $610     $610       $0
# 6                        Sikorsky Aircraft   $4,457   $1,416   $2,899
# 7              Lockheed Martin Aeronautics  $46,870   $6,090  $40,613
# 8   Lockheed Martin Information Technology     $250       $0     $250
# 9            Lockheed Martin Space Systems   $2,883     $781   $1,640
# 10                         Savi Technology     $350     $350       $0
# 11                       Sikorsky Aircraft  $10,629   $4,279   $6,350
# 12             Lockheed Martin Aeronautics  $22,539   $1,250  $20,825
# 13  Lockheed Martin Information Technology     $500       $0     $500
# 14           Lockheed Martin Space Systems     $951       $0     $951
# 15             Lockheed Martin Aeronautics  $36,385   $1,250  $35,135
# 16  Lockheed Martin Information Technology     $401       $0     $401
# 17        Lockheed Martin Missiles & Space     $250     $250       $0
# 18           Lockheed Martin Space Systems   $6,674   $3,724   $2,450
# 19                         Savi Technology     $500     $250     $250
# 20                Lockheed Martin Aculight     $250     $250       $0
# 21             Lockheed Martin Aeronautics  $13,728       $0  $13,728
# 22  Lockheed Martin Information Technology     $500     $500       $0
# 23        Lockheed Martin Missiles & Space   $1,100     $800     $300
# 24           Lockheed Martin Space Systems     $500     $500       $0
# 25                    Martin Marietta Corp   $8,500   $2,500   $6,000
# 26                      Aspen Systems Corp     $300     $300       $0
# 27                             COMSAT Corp     $500       $0     $500
# 28             Lockheed Martin Aeronautics  $36,157   $1,050  $34,552
# 29      Lockheed Martin Electronic Systems   $1,000   $1,000       $0
# 30         Lockheed Martin Energy Research     $400       $0     $400
# 31  Lockheed Martin Information Technology     $750       $0     $750
# 32        Lockheed Martin Missiles & Space     $750     $500     $250
# 33           Lockheed Martin Space Systems   $3,908   $1,158   $2,750
# 34                         Savi Technology   $2,250   $1,750     $500
# 35                            Sippican Inc  $19,800  $15,500   $4,300
# 36                      Aspen Systems Corp   $1,500   $1,500       $0
# 37                             COMSAT Corp     $750       $0     $750
# 38             Lockheed Martin Aeronautics   $1,900       $0   $1,900
# 39         Lockheed Martin Energy Research   $1,000   $1,000       $0
# 40           Lockheed Martin Space Systems     $700     $700       $0
# 41                            Orincon Corp   $9,460   $2,460   $7,000
# 42                         Orincon Sygenex   $1,000       $0   $1,000
# 43            Sandia National Laboratories  $35,433  $13,583  $20,650
# 44                         Savi Technology   $3,750   $2,750   $1,000
#
#    pct_to_dems pct_to_repubs   indivs pacs
# 0           0%          100%     $388   $0
# 1           6%           91%  $22,066   $0
# 2          69%           31%     $480   $0
# 3          56%           44%     $706   $0
# 4           0%          100%     $700   $0
# 5         100%            0%     $610   $0
# 6          32%           65%   $4,457   $0
# 7          13%           87%  $46,870   $0
# 8           0%          100%     $250   $0
# 9          27%           57%   $2,421   $0
# 10        100%            0%     $350   $0
# 11         40%           60%  $10,629   $0
# 12          6%           92%  $22,539   $0
# 13          0%          100%     $500   $0
# 14          0%          100%     $951   $0
# 15          3%           97%  $36,385   $0
# 16          0%          100%     $401   $0
# 17        100%            0%     $250   $0
# 18         56%           37%   $6,174   $0
# 19         50%           50%     $500   $0
# 20        100%            0%     $250   $0
# 21          0%          100%  $13,728   $0
# 22        100%            0%     $500   $0
# 23         73%           27%   $1,100   $0
# 24        100%            0%     $500   $0
# 25         29%           71%   $8,500   $0
# 26        100%            0%     $300   $0
# 27          0%          100%     $500   $0
# 28          3%           96%  $35,602   $0
# 29        100%            0%   $1,000   $0
# 30          0%          100%     $400   $0
# 31          0%          100%     $750   $0
# 32         67%           33%     $750   $0
# 33         30%           70%   $3,908   $0
# 34         78%           22%   $2,250   $0
# 35         78%           22%  $19,800   $0
# 36        100%            0%   $1,500   $0
# 37          0%          100%     $750   $0
# 38          0%          100%   $1,900   $0
# 39        100%            0%   $1,000   $0
# 40        100%            0%     $700   $0
# 41         26%           74%   $9,460   $0
# 42          0%          100%   $1,000   $0
# 43         38%           58%  $35,233   $0
# 44         73%           27%   $3,750   $0

# %% [markdown]
# #### Exploring groupings of contractors names (from USA Spending)

# %%
contractors_2018 = pd.read_csv('flatiron_mod3proj/contractors2018_ALL.csv')
print(contractors_2018.shape)
contractors_2018.head()

# %%
c = contractors_2018.copy()
c.columns = ['idx','contractor_name']
c['prefix'] = c.contractor_name.str[:3].astype(str)
c['prefix_len'] = c.prefix.apply(lambda x: len(x))
# c = c[c.prefix_len == 3]

c.groupby('prefix').size().sort_values(ascending=False).head(10)
